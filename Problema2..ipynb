# %% [markdown]
# # Excluindo dados no panda

# %%
import pandas as pd

# %%
HRdados = pd.read_csv("C:/Users/Ana Carolinne S/Desktop/HR/HR_Engagement_Sat_Sales_UpdatedV4.0.csv", sep= ',' , encoding='UTF-8')

# %%
HRdados.head()
# Out:
#    ID      Name       Department     GEO             Role  Rising_Star  \
# 0   1    BRADDY       Operations      US               VP          NaN
# 1   2     BORST            Sales      UK  Senior Director          NaN
# 2   3  BIRDWELL          Finance  France  Senior Director          NaN
# 3   4      BENT  Human Resources   China  Senior Director          NaN
# 4   5     BAZAN               IT   Korea         Director          NaN
#
#    Will_Relocate  Critical  Trending Perf  Talent_Level  ...  \
# 0              0       1.0              3             6  ...
# 1              0       NaN              3             6  ...
# 2              0       NaN              3             6  ...
# 3              0       NaN              3             6  ...
# 4              0       NaN              3             6  ...
#
#    Emp_Competitive_4  Emp_Competitive_5  Emp_Collaborative_1  \
# 0                  2                  2                    2
# ...

# %%
HRdados.drop(columns= "Rising_Star" , inplace= True ) 
#exluindo coluna "Rising_Star" com o Drop
#Foram usados 3 parâmetros para o método drop(). 
#1. A coluna que queremos excluir
#2. As alterações devem ser feitas no DataFrame original, sem criar cópias

# %%
HRdados.head() 
#Agora a coluna "Rising_Star" não existe mais
# Out:
#    ID      Name       Department     GEO             Role  Will_Relocate  \
# 0   1    BRADDY       Operations      US               VP              0
# 1   2     BORST            Sales      UK  Senior Director              0
# 2   3  BIRDWELL          Finance  France  Senior Director              0
# 3   4      BENT  Human Resources   China  Senior Director              0
# 4   5     BAZAN               IT   Korea         Director              0
#
#    Critical  Trending Perf  Talent_Level  Validated_Talent_Level  ...  \
# 0       1.0              3             6                       6  ...
# 1       NaN              3             6                       6  ...
# 2       NaN              3             6                       6  ...
# 3       NaN              3             6                       6  ...
# 4       NaN              3             6                       6  ...
#
#    Emp_Competitive_4  Emp_Competitive_5  Emp_Collaborative_1  \
# ...
